# %%
## DB CONNECTION
## data source: https://www.kaggle.com/datasets/mayurkadam9833/top-100-imdb-movies?resource=download

# %%
! pip install sqlalchemy pymysql pandas
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.0/45.0 kB 3.5 MB/s eta 0:00:00
# ...

# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
df = pd.read_csv('TOP 100 IMDB MOVIES.csv')
df
# Out:
#     rank                                title  \
# 0     18  Spider-Man: Across the Spider-Verse
# 1     32                          Oppenheimer
# 2     77                                Joker
# 3     76                    Avengers: Endgame
# 4     37                             Parasite
# ..   ...                                  ...
# 95    99                         Citizen Kane
# 96    65                   The Great Dictator
# 97    49                         Modern Times
# 98    54                          City Lights
# 99   100                                    M
#
#                                           description  \
# 0   Miles Morales catapults across the Multiverse,...
# 1   The story of American scientist, J. Robert Opp...
# 2   A mentally troubled stand-up comedian embarks ...
# 3   After the devastating events of Avengers: Infi...
# 4   Greed and class discrimination threaten the ne...
# ..                                                ...
# ...

# %%
username = 'shveta'
password = 'Sunset96!'
hostname = 'sharma-mysql-3.mysql.database.azure.com'
database = 'movies'

connection_string = f'mysql+pymysql://{username}:{password}@{hostname}/{database}'

engine = create_engine(connection_string)

# %%
df.to_sql('rating', engine, if_exists='replace')
# Out:
# 100

# %%
query = '''
SELECT title, year, rating
FROM rating
WHERE rating >= 9.0
ORDER BY rating DESC;
'''

# %%
test_return = pd.read_sql(query, engine)
test_return
# Out:
#                                            title  year  rating
# 0                       The Shawshank Redemption  1994     9.3
# 1                                  The Godfather  1972     9.2
# 2                                The Dark Knight  2008     9.0
# 3  The Lord of the Rings: The Return of the King  2003     9.0
# 4                               Schindler's List  1993     9.0
# 5                          The Godfather Part II  1974     9.0
# 6                                   12 Angry Men  1957     9.0
